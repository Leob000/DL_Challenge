# %%
import pandas as pd

# %%
df = pd.read_parquet('data/meteo.parquet')
df
# Out:
#        numer_sta                      date      pmer   tend cod_tend     dd  \
# 0          07020 2017-09-23 02:00:00+02:00  102290.0    0.0        4  160.0
# 1          07558 2017-09-23 02:00:00+02:00  102180.0  -40.0        8   30.0
# 2          07661 2017-09-23 05:00:00+02:00  102090.0 -110.0        7   60.0
# 3          07117 2017-09-23 08:00:00+02:00  102070.0  -50.0        6   90.0
# 4          07621 2017-09-23 11:00:00+02:00  101950.0  -30.0        6  340.0
# ...          ...                       ...       ...    ...      ...    ...
# 695155     07335 2022-12-17 16:00:00+01:00  102170.0  -40.0        5   70.0
# 695156     07149 2022-12-17 19:00:00+01:00  102600.0   50.0        3  100.0
# 695157     07510 2022-12-17 19:00:00+01:00  102020.0   80.0        3   80.0
# 695158     07621 2022-12-17 22:00:00+01:00  102210.0  130.0        1  160.0
# 695159     07168 2022-12-18 01:00:00+01:00  102690.0  -20.0        8   80.0
#
# ...

# %%
df['date'].describe()
# Out:
# count                              695160
# mean     2019-12-31 08:28:52.573000+01:00
# min             2017-01-01 01:00:00+01:00
# 25%             2018-07-01 20:00:00+02:00
# 50%             2019-12-30 05:30:00+01:00
# 75%             2021-06-30 08:00:00+02:00
# max             2022-12-31 22:00:00+01:00
# Name: date, dtype: object
